# %%
import pandas as pd
import numpy as np
import os

# %%
df = pd.read_pickle('/home/wangyuting/share/quant/wangyuting/liangjian/alpha/data/量价资金数据_concept_new.pkl')
df
# Out:
#         code       date           amt      close       high        low
# 0  884001.WI 2016-01-04  5.527776e+09  2042.9818  2235.9626  2042.9818  \
# 1  884001.WI 2016-01-05  7.078281e+09  2013.0848  2040.9922  1923.2858
# 2  884001.WI 2016-01-06  5.768307e+09  2071.6792  2072.0235  2009.0260
# 3  884001.WI 2016-01-07  1.478565e+09  1888.5448  2031.0403  1886.4028
# 4  884001.WI 2016-01-08  6.471676e+09  1926.6350  1961.8320  1809.9179
#
#         open       volume     开盘净主动买入额    尾盘净主动买入额  ...       净主动买入额
# 0  2235.1654  419011645.0 -216453749.0         0.0  ... -404957427.0  \
# 1  1944.8539  587879114.0  -45568307.0  26180151.0  ... -247593861.0
# 2  2014.5244  446246388.0  -17380224.0  35631702.0  ...  -31177200.0
# 3  2031.0403  119269329.0 -260462670.0         0.0  ... -110312021.0
# 4  1939.5432  541473700.0 -170219366.0 -50718127.0  ...  -58861195.0
#
#      尾盘主力净流入额  开盘净主动买入额_成交额占比  尾盘净主动买入额_成交额占比  主力净流入额_成交额占比  开盘主力净流入额_成交额占比
# ...

# %%
df['code'].unique().tolist()
# Out:
# ['884001.WI',
#  '884025.WI',
#  '884027.WI',
#  '884028.WI',
#  '884030.WI',
#  '884031.WI',
#  '884032.WI',
#  '884034.WI',
#  '884035.WI',
#  '884036.WI',
#  '884037.WI',
#  '884039.WI',
#  '884040.WI',
#  '884041.WI',
#  '884043.WI',
#  '884045.WI',
#  '884046.WI',
#  '884047.WI',
#  '884048.WI',
#  '884050.WI',
#  '884052.WI',
#  '884053.WI',
#  '884057.WI',
#  '884059.WI',
#  '884061.WI',
#  '884062.WI',
#  '884068.WI',
#  '884069.WI',
#  '884073.WI',
#  '884074.WI',
#  '884075.WI',
#  '884076.WI',
#  '884077.WI',
#  '884079.WI',
#  '884080.WI',
#  '884081.WI',
#  '884086.WI',
#  '884087.WI',
#  '884088.WI',
#  '884089.WI',
#  '884090.WI',
#  '884091.WI',
#  '884092.WI',
#  '884093.WI',
#  '884095.WI',
#  '884096.WI',
#  '884097.WI',
#  '884098.WI',
#  '884099.WI',
#  '884100.WI',
#  '8841000.WI',
#  '8841001.WI',
#  '8841002.WI',
#  '8841004.WI',
#  '8841005.WI',
#  '8841006.WI',
#  '8841007.WI',
#  '884101.WI',
#  '8841011.WI',
#  '8841013.WI',
#  '8841014.WI',
# ...
